# %%
class Test:
    def __init__(self,a,b):
        self.a=a
        self.b=b

# %%
t=Test(0,1)

# %%
t.a
# Out:
# 0

# %%
t.b
# Out:
# 1

# %%
t.a=102

# %%
t.a
# Out:
# 102

# %%
class car:
    def __init__(self,year,model):
        self.__year=year
        self.__model=model

# %%
obj_car=car(2003,1)

# %%
obj_car.car_year=2005

# %%
obj_car.car_year
# Out:
# 2005

# %%
class bank_acc:
    def __init__(self,balance):
        self.__balance=balance
        
    def deposit(self,amount):
            self.__balance=self.__balance+amount
            
    def withdraw(self,amount):
        if self.__balance>=amount:
            self.__balance=self.__balance-amount
            return True
        else:
            return False
    def get_balance(self):
        return self.__balance

# %%
obj_bank_acc=bank_acc(1500)

# %%
obj_bank_acc.deposit(1000)

# %%
obj_bank_acc.withdraw(5000)
# Out:
# False

# %%
obj_bank_acc.get_balance()
# Out:
# 2500

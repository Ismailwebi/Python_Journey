# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
d={'name':"ismail",'name':'ismail','rollno':'20211csd0176'}

# %%
d
# Out:
# {'name': 'ismail', 'rollno': '20211csd0176'}

# %%
a={(1,2,3):'abc'}
#it accepts only tuples as key

# %%
a
# Out:
# {(1, 2, 3): 'abc'}

# %%
b={'courses':['data science','java with system design','machine learning']}

# %%
b
# Out:
# {'courses': ['data science', 'java with system design', 'machine learning']}

# %%
c={'key':{1,2,3,4}}

# %%
c
# Out:
# {'key': {1, 2, 3, 4}}

# %%
e={'key':{'name':'ismail'}}

# %%
e
# Out:
# {'key': {'name': 'ismail'}}

# %%
#value can be anything i.e tuple,set,dict,list for the key but key can be only tuples

# %%
b['timings']=(12,12,12)

# %%
b
# Out:
# {'courses': ['data science', 'java with system design', 'machine learning'],
#  'timings': (12, 12, 12)}

# %%
b['courses']
# Out:
# ['data science', 'java with system design', 'machine learning']

# %%
type(b['courses'])
# Out:
# list

# %%
b['name']='ismail'

# %%
b
# Out:
# {'courses': ['data science', 'java with system design', 'machine learning'],
#  'timings': (12, 12, 12),
#  'name': 'ismail'}

# %%
b['name'].upper()
# Out:
# 'ISMAIL'

# %%
d1={'key':{'name':'ismail','class':'csd'}}

# %%
d1
# Out:
# {'key': {'name': 'ismail', 'class': 'csd'}}

# %%
d1['key']
# Out:
# {'name': 'ismail', 'class': 'csd'}

# %%
d1['key']['class']
# Out:
# 'csd'

# %%
d1['key1']='abc'

# %%
d1
# Out:
# {'key': {'name': 'ismail', 'class': 'csd'}, 'key1': 'abc'}

# %%
a=d1.copy()

# %%
a
# Out:
# {'key': {'name': 'ismail', 'class': 'csd'}, 'key1': 'abc'}

# %%
d1.clear()

# %%
d1
# Out:
# {}

# %%
len(a)
# Out:
# 2

# %%
a.keys()
# Out:
# dict_keys(['key', 'key1'])

# %%
a.values()
# Out:
# dict_values([{'name': 'ismail', 'class': 'csd'}, 'abc'])

# %%
list(a.values())
# Out:
# [{'name': 'ismail', 'class': 'csd'}, 'abc']

# %%
list(a)
# Out:
# ['key', 'key1']

# %%
list(a.items())
# Out:
# [('key', {'name': 'ismail', 'class': 'csd'}), ('key1', 'abc')]

# %%
del a['key']

# %%
a
# Out:
# {'key1': 'abc'}

# %%
a.pop('key1')
# Out:
# 'abc'

# %%
a
# Out:
# {}

# %%
d2={'key':'value1','key2':'value2'}

# %%
d3={'key3':'value3','key4':'value4'}

# %%
[d2,d3]
# Out:
# [{'key': 'value1', 'key2': 'value2'}, {'key3': 'value3', 'key4': 'value4'}]

# %%
d2.update(d3)

# %%
d2
# Out:
# {'key': 'value1', 'key2': 'value2', 'key3': 'value3', 'key4': 'value4'}

# %%
d2.get('key')
# Out:
# 'value1'

# %%
{i**2 for i in range(1,11)}
# Out:
# {1, 4, 9, 16, 25, 36, 49, 64, 81, 100}

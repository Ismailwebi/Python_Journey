# %%
a={}

# %%
type(a)
# Out:
# dict

# %%
b={1,2,3,4,5}

# %%
type(b)
# Out:
# set

# %%
c={1,1,1,2,3,4,4,5,5,5,6,6,6}

# %%
c
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
c[0]
#it does not allow to extract element due to its properties uniqueness
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 c[0]
#
# TypeError: 'set' object is not subscriptable

# %%
d={1,2,3,4,'ismail','Ismail'}

# %%
d
# Out:
# {1, 2, 3, 4, 'Ismail', 'ismail'}

# %%
for i in d:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# Ismail
# ismail

# %%
1 in d
# Out:
# True

# %%
d.add(2)

# %%
d
# Out:
# {1, 2, 3, 4, 'Ismail', 'ismail'}

# %%
d.add(23)

# %%
d
# Out:
# {1, 2, 23, 3, 4, 'Ismail', 'ismail'}

# %%
d.pop()
# Out:
# 1

# %%
d.pop()
# Out:
# 2

# %%
d.clear()

# %%
d
# Out:
# set()

# %%
d={1,2,3,4}

# %%
d
# Out:
# {1, 2, 3, 4}

# %%
D=d.copy()

# %%
D
# Out:
# {1, 2, 3, 4}

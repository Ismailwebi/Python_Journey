# %%
t=()
#tuple is immutable where you cannot change element in that particular index

# %%
type(t)
# Out:
# tuple

# %%
a=[1,2,3,'osmail']

# %%
a
# Out:
# [1, 2, 3, 'osmail']

# %%
b=(1,2,3,3,44,44)

# %%
b
# Out:
# (1, 2, 3, 3, 44, 44)

# %% [markdown]
# b[::-1]

# %%
b.count(3)
#tuples has only two built in function that is index and count
# Out:
# 2

# %%
b.index(44)
# Out:
# 4

# %%
True
# Out:
# True

# %%
1 in b
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)

# %%
not int(bool(0))
# Out:
# True

# %%
not int(bool(1))
# Out:
# False

# %%
not 00
# Out:
# True

# %%
int(not (0))
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
False * False
# Out:
# 0

# %%
True * False
# Out:
# 0

# %%
False * (not(True))
# Out:
# 0

# %% [markdown]
# #Strings

# %%
a='ismail'

# %%
a
# Out:
# 'ismail'

# %%
b="zaid"

# %%
b
# Out:
# 'zaid'

# %%
a[0]
# Out:
# 'i'

# %%
#immutable
a[0]=a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 #immutable
# ----> 2 a[0]=a
#
# TypeError: 'str' object does not support item assignment

# %%
a[5:]

# %%
a[2:3]

# %%
a[-1:]
# Out:
# 'l'

# %%
a[-1]
# Out:
# 'l'

# %%
a[:-1]
# Out:
# 'ismai'

# %%
a[1:3]
# Out:
# 'sm'

# %%
a[-1:3]
# Out:
# ''

# %%
b="hello im a ismail"

# %%
b[:-2]
# Out:
# 'hello im a isma'

# %%
b[::-1]
# Out:
# 'liamsi a mi olleh'

# %%
b[::-2]
# Out:
# 'las  iolh'

# %%
b[-1:]
# Out:
# 'l'

# %%
b[:-1]
# Out:
# 'hello im a ismai'

# %%
b[:1]
# Out:
# 'h'

# %%
countt=count(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 countt=count(b)
#
# NameError: name 'count' is not defined

# %%
print(b.count(b))
# Out:
# 1

# %%
b[5::-1]
# Out:
# ' olleh'

# %%
b
# Out:
# 'hello im a ismail'

# %%
b[10:5:-1]
# Out:
# ' a mi'

# %%
z=b*2

# %%
len(b)
# Out:
# 17

# %%
b
# Out:
# 'hello im a ismail'

# %%
len(b)
# Out:
# 17

# %%
len(z)
# Out:
# 34

# %%
#find()
b.find("m")
# Out:
# 7

# %%
b.find("i",1,5)
# Out:
# -1

# %%
#count()
b.count('a')
# Out:
# 2

# %%
b.count(" ")
# Out:
# 3

# %%
#split
b.split(' ')
# Out:
# ['hello', 'im', 'a', 'ismail']

# %%
b.split('  ')
# Out:
# ['hello im a ismail']

# %%
b.split('s')
# Out:
# ['hello im a i', 'mail']

# %%
splitt=b.split('i')

# %%
print(splitt)
# Out:
# ['hello ', 'm a ', 'sma', 'l']

# %%
b.upper()
# Out:
# 'HELLO IM A ISMAIL'

# %%
b.lower()
# Out:
# 'hello im a ismail'

# %%
b.swapcase()
# Out:
# 'HELLO IM A ISMAIL'

# %%
b
# Out:
# 'hello im a ismail'

# %%
k="Hello Im in London"

# %%
k
# Out:
# 'Hello Im in London'

# %%
k.swapcase()
# Out:
# 'hELLO iM IN lONDON'

# %%
D='Data Sticks'

# %%
D
# Out:
# 'Data Sticks'

# %%
D.swapcase()
# Out:
# 'dATA sTICKS'

# %%
namee="hello im a faizan"

# %%
namee[::-1]
# Out:
# 'naziaf a mi olleh'

# %%
namee.upper()
# Out:
# 'HELLO IM A FAIZAN'
